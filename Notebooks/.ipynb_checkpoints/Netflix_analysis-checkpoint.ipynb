# %%
pip install pandas numpy matplotlib seaborn plotly geopandas kaleido
# Out:
# Requirement already satisfied: pandas in c:\users\raj_s\anaconda3\lib\site-packages (2.2.3)
# Requirement already satisfied: numpy in c:\users\raj_s\anaconda3\lib\site-packages (2.1.3)
# Requirement already satisfied: matplotlib in c:\users\raj_s\anaconda3\lib\site-packages (3.10.0)
# Requirement already satisfied: seaborn in c:\users\raj_s\anaconda3\lib\site-packages (0.13.2)
# Requirement already satisfied: plotly in c:\users\raj_s\anaconda3\lib\site-packages (5.24.1)
# Collecting geopandas
#   Downloading geopandas-1.1.3-py3-none-any.whl.metadata (2.3 kB)
# Collecting kaleido
#   Downloading kaleido-1.3.0-py3-none-any.whl.metadata (5.6 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\raj_s\anaconda3\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\raj_s\anaconda3\lib\site-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\raj_s\anaconda3\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\raj_s\anaconda3\lib\site-packages (from matplotlib) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\raj_s\anaconda3\lib\site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\raj_s\anaconda3\lib\site-packages (from matplotlib) (4.55.3)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\raj_s\anaconda3\lib\site-packages (from matplotlib) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in c:\users\raj_s\anaconda3\lib\site-packages (from matplotlib) (24.2)
# Requirement already satisfied: pillow>=8 in c:\users\raj_s\anaconda3\lib\site-packages (from matplotlib) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\raj_s\anaconda3\lib\site-packages (from matplotlib) (3.2.0)
# Requirement already satisfied: tenacity>=6.2.0 in c:\users\raj_s\anaconda3\lib\site-packages (from plotly) (9.0.0)
# Collecting pyogrio>=0.7.2 (from geopandas)
#   Downloading pyogrio-0.12.1-cp313-cp313-win_amd64.whl.metadata (6.0 kB)
# Collecting pyproj>=3.5.0 (from geopandas)
#   Downloading pyproj-3.7.2-cp313-cp313-win_amd64.whl.metadata (31 kB)
# Collecting shapely>=2.0.0 (from geopandas)
#   Downloading shapely-2.1.2-cp313-cp313-win_amd64.whl.metadata (7.1 kB)
# Collecting choreographer>=1.3.0 (from kaleido)
#   Downloading choreographer-1.3.0-py3-none-any.whl.metadata (6.9 kB)
# Collecting logistro>=1.0.8 (from kaleido)
#   Downloading logistro-2.0.1-py3-none-any.whl.metadata (3.9 kB)
# Collecting orjson>=3.10.15 (from kaleido)
#   Downloading orjson-3.11.9-cp313-cp313-win_amd64.whl.metadata (43 kB)
# Requirement already satisfied: platformdirs>=4.3.6 in c:\users\raj_s\anaconda3\lib\site-packages (from choreographer>=1.3.0->kaleido) (4.3.7)
# Collecting simplejson>=3.19.3 (from choreographer>=1.3.0->kaleido)
#   Downloading simplejson-4.1.1-cp313-cp313-win_amd64.whl.metadata (3.9 kB)
# Requirement already satisfied: certifi in c:\users\raj_s\anaconda3\lib\site-packages (from pyogrio>=0.7.2->geopandas) (2025.4.26)
# Requirement already satisfied: six>=1.5 in c:\users\raj_s\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Downloading geopandas-1.1.3-py3-none-any.whl (342 kB)
# Downloading kaleido-1.3.0-py3-none-any.whl (55 kB)
# Downloading choreographer-1.3.0-py3-none-any.whl (52 kB)
# Downloading logistro-2.0.1-py3-none-any.whl (8.6 kB)
# Downloading orjson-3.11.9-cp313-cp313-win_amd64.whl (127 kB)
# Downloading pyogrio-0.12.1-cp313-cp313-win_amd64.whl (22.9 MB)
#    ---------------------------------------- 0.0/22.9 MB ? eta -:--:--
#    ---------------------------------------- 0.0/22.9 MB ? eta -:--:--
#    ---------------------------------------- 0.0/22.9 MB ? eta -:--:--
#    ---------------------------------------- 0.3/22.9 MB ? eta -:--:--
#    ---------------------------------------- 0.3/22.9 MB ? eta -:--:--
#     --------------------------------------- 0.5/22.9 MB 790.9 kB/s eta 0:00:29
#     --------------------------------------- 0.5/22.9 MB 790.9 kB/s eta 0:00:29
#     --------------------------------------- 0.5/22.9 MB 790.9 kB/s eta 0:00:29
#    - -------------------------------------- 0.8/22.9 MB 563.5 kB/s eta 0:00:40
#    - -------------------------------------- 0.8/22.9 MB 563.5 kB/s eta 0:00:40
#    - -------------------------------------- 1.0/22.9 MB 536.1 kB/s eta 0:00:41
#    - -------------------------------------- 1.0/22.9 MB 536.1 kB/s eta 0:00:41
#    - -------------------------------------- 1.0/22.9 MB 536.1 kB/s eta 0:00:41
#    -- ------------------------------------- 1.3/22.9 MB 549.1 kB/s eta 0:00:40
#    -- ------------------------------------- 1.6/22.9 MB 601.8 kB/s eta 0:00:36
win_amd64.whl (1.7 MB)
#    ---------------------------------------- 0.0/1.7 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.7 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.7 MB ? eta -:--:--
#    ------ --------------------------------- 0.3/1.7 MB ? eta -:--:--
#    ------------ --------------------------- 0.5/1.7 MB 831.8 kB/s eta 0:00:02
#    ------------ --------------------------- 0.5/1.7 MB 831.8 kB/s eta 0:00:02
#    ------------------------ --------------- 1.0/1.7 MB 1.1 MB/s eta 0:00:01
#    ------------------------------ --------- 1.3/1.7 MB 1.2 MB/s eta 0:00:01
#    ---------------------------------------- 1.7/1.7 MB 1.3 MB/s eta 0:00:00
# Downloading simplejson-4.1.1-cp313-cp313-win_amd64.whl (90 kB)
# Installing collected packages: simplejson, shapely, pyproj, pyogrio, orjson, logistro, choreographer, kaleido, geopandas
#
#    ---------------------------------------- 0/9 [simplejson]
#    ---------------------------------------- 0/9 [simplejson]
#    ---------------------------------------- 0/9 [simplejson]
#    ---- ----------------------------------- 1/9 [shapely]
#    ---- ----------------------------------- 1/9 [shapely]
#    ---- ----------------------------------- 1/9 [shapely]
#    ---- ----------------------------------- 1/9 [shapely]
#    ---- ----------------------------------- 1/9 [shapely]
#    ---- ----------------------------------- 1/9 [shapely]
#    ---- ----------------------------------- 1/9 [shapely]
#    ---- ----------------------------------- 1/9 [shapely]
#    ---- ----------------------------------- 1/9 [shapely]
#    ---- ----------------------------------- 1/9 [shapely]
#    -------- ------------------------------- 2/9 [pyproj]
#    -------- ------------------------------- 2/9 [pyproj]
#    -------- ------------------------------- 2/9 [pyproj]
#    -------- ------------------------------- 2/9 [pyproj]
#    ------------- -------------------------- 3/9 [pyogrio]
#    ------------- -------------------------- 3/9 [pyogrio]
#    ------------- -------------------------- 3/9 [pyogrio]
#    ------------- -------------------------- 3/9 [pyogrio]
#    ------------- -------------------------- 3/9 [pyogrio]
#    ------------- -------------------------- 3/9 [pyogrio]
#    ------------- -------------------------- 3/9 [pyogrio]
#    ------------- -------------------------- 3/9 [pyogrio]
#    ------------- -------------------------- 3/9 [pyogrio]
#    -------------------------- ------------- 6/9 [choreographer]
#    -------------------------- ------------- 6/9 [choreographer]
#    -------------------------- ------------- 6/9 [choreographer]
#    ------------------------------- -------- 7/9 [kaleido]
#    ----------------------------------- ---- 8/9 [geopandas]
#    ----------------------------------- ---- 8/9 [geopandas]
#    ----------------------------------- ---- 8/9 [geopandas]
#    ----------------------------------- ---- 8/9 [geopandas]
#    ----------------------------------- ---- 8/9 [geopandas]
#    ----------------------------------- ---- 8/9 [geopandas]
#    ----------------------------------- ---- 8/9 [geopandas]
#    ----------------------------------- ---- 8/9 [geopandas]
#    ---------------------------------------- 9/9 [geopandas]
#
# Successfully installed choreographer-1.3.0 geopandas-1.1.3 kaleido-1.3.0 logistro-2.0.1 orjson-3.11.9 pyogrio-0.12.1 pyproj-3.7.2 shapely-2.1.2 simplejson-4.1.1
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# Display settings
pd.set_option('display.max_columns', None)
plt.rcParams['figure.figsize'] = (12, 6)

# %%
df = pd.read_csv('/Netflix_analysis/data/netflix_titles.csv')

print("Shape:", df.shape)
print("\nColumn names:", df.columns.tolist())
print("\nMissing values:\n", df.isnull().sum())
df.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 df = pd.read_csv('/Netflix_analysis/data/netflix_titles.csv')
#       3 print("Shape:", df.shape)
#       4 print("\nColumn names:", df.columns.tolist())
#
# File ~\anaconda3\Lib\site-packages\pandas\io\parsers\readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1013 kwds_defaults = _refine_defaults_read(
#    1014     dialect,
#    1015     delimiter,
#    (...)
#    1022     dtype_backend=dtype_backend,
#    1023 )
#    1024 kwds.update(kwds_defaults)
# -> 1026 return _read(filepath_or_buffer, kwds)
#
# File ~\anaconda3\Lib\site-packages\pandas\io\parsers\readers.py:620, in _read(filepath_or_buffer, kwds)
#     617 _validate_names(kwds.get("names", None))
#     619 # Create the parser.
# --> 620 parser = TextFileReader(filepath_or_buffer, **kwds)
#     622 if chunksize or iterator:
#     623     return parser
#
# File ~\anaconda3\Lib\site-packages\pandas\io\parsers\readers.py:1620, in TextFileReader.__init__(self, f, engine, **kwds)
#    1617     self.options["has_index_names"] = kwds["has_index_names"]
#    1619 self.handles: IOHandles | None = None
# -> 1620 self._engine = self._make_engine(f, self.engine)
#
# File ~\anaconda3\Lib\site-packages\pandas\io\parsers\readers.py:1880, in TextFileReader._make_engine(self, f, engine)
#    1878     if "b" not in mode:
#    1879         mode += "b"
# -> 1880 self.handles = get_handle(
#    1881     f,
#    1882     mode,
#    1883     encoding=self.options.get("encoding", None),
#    1884     compression=self.options.get("compression", None),
#    1885     memory_map=self.options.get("memory_map", False),
#    1886     is_text=is_text,
#    1887     errors=self.options.get("encoding_errors", "strict"),
#    1888     storage_options=self.options.get("storage_options", None),
#    1889 )
#    1890 assert self.handles is not None
#    1891 f = self.handles.handle
#
# File ~\anaconda3\Lib\site-packages\pandas\io\common.py:873, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     868 elif isinstance(handle, str):
#     869     # Check whether the filename is to be opened in binary mode.
#     870     # Binary mode does not support 'encoding' and 'newline'.
#     871     if ioargs.encoding and "b" not in ioargs.mode:
#     872         # Encoding
# --> 873         handle = open(
#     874             handle,
#     875             ioargs.mode,
#     876             encoding=ioargs.encoding,
#     877             errors=errors,
#     878             newline="",
#     879         )
#     880     else:
#     881         # Binary mode
#     882         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: '/Netflix_analysis/data/netflix_titles.csv'
